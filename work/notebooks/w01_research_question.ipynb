# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/maryam884/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
# ANSWER : I selected the Refresh / Content Opportunity Scoring lane because the goal is practical: identify which pages should be reviewed first for refresh, expansion, protection, or monitoring. The decision this work supports is how a team should prioritize limited time and resources across many pages. I chose this lane because it produces a ranked action queue with reason codes, which makes the recommendations easy to explain and act on. This is not about replacing human judgment; it is about helping reviewers focus on the pages with the strongest evidence of opportunity or risk.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# Research Question: Which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring?
# Decision: Decide which pages deserve attention first when a team cannot review everything.
# Unit of Analysis: One content page.
# Output: A ranked review queue with a score, confidence label, and reason codes.
# Action: A reviewer can choose to refresh content, improve metadata, expand content depth, monitor performance, or leave the page unchanged.
# Cost of a Wrong Recommendation: A false positive wastes reviewer time on pages that do not need attention. A false negative means a valuable page with decline risk or improvement potential may be missed.
# Why ML Helps: The dataset contains thousands of pages and many signals, making it difficult for a human to manually prioritize every page. ML can combine multiple observed signals into a ranking that helps reviewers focus their effort.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
#
#
# The starter dataset contains 30,000 content pages with 44 features, making manual review difficult. The average page has 5,200.37 impressions and 37.07 sessions over the measured period. In addition, 54.21% of the pages are showing a declining trend, which suggests there are many pages that may require review or improvement. These numbers show that prioritizing pages using data and machine learning could help teams focus their effort more effectivel

# %%
import pandas as pd
import os # Import os module

file_path = 'data/raw/content_refresh_anonymized.csv'

if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the file is uploaded to the correct directory or adjust the file_path variable.")
else:
    df = pd.read_csv(file_path)

    print('Rows, Columns:', df.shape)
    print('Average impressions (90d):', round(df['impressions_90d'].mean(), 2))
    print('Average sessions (90d):', round(df['sessions_90d'].mean(), 2))
    print('Percentage of declining pages:', round((df['trend_direction'] == 'down').mean() * 100, 2), '%')
# Out:
# Rows, Columns: (30000, 44)
# Average impressions (90d): 5200.37
# Average sessions (90d): 37.07
# Percentage of declining pages: 54.21 %

# %%
# !git clone https://github.com/maryam884/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 119 (delta 35), reused 95 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 13.58 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd flyrank-ml-internship
# !ls
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# Answer :
# This project is a decision-support tool, not a system that proves causation. It can identify observed patterns and rank pages by estimated opportunity or risk, but it cannot prove that refreshing a page will cause traffic growth. The results are directional and based on the available signals in the dataset. Human review is still required before taking action, and future results may differ because of seasonality, market changes, or other factors not captured in the data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
