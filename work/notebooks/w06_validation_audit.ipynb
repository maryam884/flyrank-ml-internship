# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/maryam884/flyrank-ml-internship/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*
#
# Finding 1
# The paper reports that its ranking approach improves content prioritization compared with baseline methods.
# Methodology question: How were the labels created? If labels depend on future performance or manual review, the paper should clearly describe this process so readers can judge whether the model can generalize to new data.
# Finding 2
# The paper reports strong evaluation performance.
# Methodology question: Does the validation strategy reflect real deployment? A grouped-by-client or time-aware evaluation would help show whether the model performs well on unseen clients or future content instead of similar examples from the training data. clients or future content.

# %%
# Record the two findings being reviewed

paper_findings = [
    "Ranking approach improves content prioritization.",
    "Validation shows strong model performance."
]

print("Number of findings reviewed:", len(paper_findings))

for i, finding in enumerate(paper_findings, start=1):
    print(f"Finding {i}: {finding}")
# Out:
# Number of findings reviewed: 2
# Finding 1: Ranking approach improves content prioritization.
# Finding 2: Validation shows strong model performance.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*
#
# My Week 5 model originally used a random 80/20 train-test split. This provides a simple comparison with the baseline, but it may produce optimistic results if similar records appear in both the training and test sets. A grouped or time-aware split would better represent how the model would be used in practice and would provide a more reliable estimate of performance.

# %%
print("Original random split accuracy:", model_acc)

print("\nGrouped or time-aware validation could not be demonstrated because")
print("the sample dataset does not include a client identifier or timestamp.")
print("In a production setting, this model should be evaluated using")
print("grouped-by-client or time-aware validation.")
# Out:
# Original random split accuracy: 1.0
#
# Grouped or time-aware validation could not be demonstrated because
# the sample dataset does not include a client identifier or timestamp.
# In a production setting, this model should be evaluated using
# grouped-by-client or time-aware validation.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*
#
# This model uses days_since_last_update as an input feature, and the target label is partly created using the same variable. Because the target depends directly on this feature, the model can easily learn the rule that defines the label. This likely explains the perfect accuracy observed during evaluation. While this setup is acceptable for demonstrating the modeling workflow, a production model should use independently collected labels to avoid overly optimistic performance estimates.
# Section 3 Code

# %%
print("Target definition:")
print("target = (days_since_last_update > 365) AND (trend_direction == 'down')")

print("\nFeatures used:")
for col in X.columns:
    print("-", col)

print("\nPotential leakage check:")

if "days_since_last_update" in X.columns:
    print(" Feature 'days_since_last_update' is also used to create the target.")
else:
    print("No obvious leakage detected.")
# Out:
# Target definition:
# target = (days_since_last_update > 365) AND (trend_direction == 'down')
#
# Features used:
# - days_since_last_update
# - impressions_90d
# - sessions_90d
# - ctr
# - avg_position
# - content_age_days
#
# Potential leakage check:
#  Feature 'days_since_last_update' is also used to create the target.

# %% [markdown]
# ## 4. Claim rewrite
#
# Original claim
# The Decision Tree accurately identifies which pages should be refreshed.
# Rewritten claim
# On this dataset, the Decision Tree observed perfect accuracy because the target label was derived from simple rule-based conditions. The measured performance should be interpreted as decision-support for this specific dataset rather than evidence that the model will generalize to new or unseen content without additional validation.

# %%
# Original claim and revised claim

original_claim = "The Decision Tree accurately identifies which pages should be refreshed."

revised_claim = (
    "On this dataset, the Decision Tree observed high accuracy and may provide "
    "decision-support for identifying pages to review. Additional validation on "
    "unseen data would be needed before making stronger claims."
)

print("Original claim:")
print(original_claim)

print("\nRewritten claim:")
print(revised_claim)
# Out:
# Original claim:
# The Decision Tree accurately identifies which pages should be refreshed.
#
# Rewritten claim:
# On this dataset, the Decision Tree observed high accuracy and may provide decision-support for identifying pages to review. Additional validation on unseen data would be needed before making stronger claims.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
